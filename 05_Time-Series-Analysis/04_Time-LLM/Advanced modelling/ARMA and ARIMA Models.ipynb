# %% [markdown]
# # ARMA and ARIMA Models

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.stattools import acf
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Simulate ARMA process (1,1)

# %%
ar1 = np.array([1, 0.33])
ma1 = np.array([1, 0.9])

simulated_ARMA_data = ArmaProcess(ar1, ma1).generate_sample(nsample=10000)

# %%
plt.figure(figsize=[15, 7.5]); # Set dimensions for figure
plt.plot(simulated_ARMA_data)
plt.title("Simulated ARMA(1,1) Process")
plt.xlim([0, 200])
plt.show()

# %%
plot_pacf(simulated_ARMA_data);
plot_acf(simulated_ARMA_data);

# %% [markdown]
# ## Simulate ARMA (2,2) process

# %%
ar2 = np.array([1, 0.33, 0.5])
ma2 = np.array([1, 0.9, 0.3])

simulated_ARMA2_data = ArmaProcess(ar1, ma1).generate_sample(nsample=10000)

# %%
plt.figure(figsize=[15, 7.5]); # Set dimensions for figure
plt.plot(simulated_ARMA2_data)
plt.title("Simulated ARMA(2,2) Process")
plt.xlim([0, 200])
plt.show()

# %%
plot_pacf(simulated_ARMA2_data);
plot_acf(simulated_ARMA2_data);

# %% [markdown]
# ## ARIMA

# %%
data = pd.read_csv('../data/jj.csv')
data.head()
# Out:
#          date  data
# 0  1960-01-01  0.71
# 1  1960-04-01  0.63
# 2  1960-07-02  0.85
# 3  1960-10-01  0.44
# 4  1961-01-01  0.61

# %%
plt.figure(figsize=[15, 7.5]); # Set dimensions for figure
plt.scatter(data['date'], data['data'])
plt.title('Quarterly EPS for Johnson & Johnson')
plt.ylabel('EPS per share ($)')
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plot_pacf(data['data']);
plot_acf(data['data']);

# %%
# Augmented Dickey-Fuller test

ad_fuller_result = adfuller(data['data'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: 2.742016573457468
# p-value: 1.0

# %%
# Take the log difference to make data stationary

data['data'] = np.log(data['data'])
data['data'] = data['data'].diff()
data = data.drop(data.index[0])
data.head()
# Out:
#          date      data
# 1  1960-04-01 -0.119545
# 2  1960-07-02  0.299517
# 3  1960-10-01 -0.658462
# 4  1961-01-01  0.326684
# 5  1961-04-02  0.123233

# %%
plt.figure(figsize=[15, 7.5]); # Set dimensions for figure
plt.plot(data['data'])
plt.title("Log Difference of Quarterly EPS for Johnson & Johnson")
plt.show()

# %%
# Augmented Dickey-Fuller test

ad_fuller_result = adfuller(data['data'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -4.317043945811833
# p-value: 0.0004149731404440715

# %%
plot_pacf(data['data']);
plot_acf(data['data']);

# %%
def optimize_ARIMA(order_list, exog):
    """
        Return dataframe with parameters and corresponding AIC
        
        order_list - list with (p, d, q) tuples
        exog - the exogenous variable
    """
    
    results = []
    
    for order in tqdm_notebook(order_list):
        try: 
            model = SARIMAX(exog, order=order).fit(disp=-1)
        except:
            continue
            
        aic = model.aic
        results.append([order, model.aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p, d, q)', 'AIC']
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
ps = range(0, 8, 1)
d = 1
qs = range(0, 8, 1)

# Create a list with all possible combination of parameters
parameters = product(ps, qs)
parameters_list = list(parameters)

order_list = []

for each in parameters_list:
    each = list(each)
    each.insert(1, 1)
    each = tuple(each)
    order_list.append(each)
    
result_df = optimize_ARIMA(order_list, exog=data['data'])

result_df
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
#     (p, d, q)         AIC
# 0   (7, 1, 1) -142.124774
# 1   (3, 1, 3) -142.041927
# 2   (7, 1, 5) -140.803674
# 3   (3, 1, 1) -140.470775
# 4   (3, 1, 4) -140.461221
# ..        ...         ...
# 59  (1, 1, 1)  -37.106604
# 60  (0, 1, 1)  -14.645882
# 61  (2, 1, 0)   14.952068
# 62  (1, 1, 0)   17.545808
# 63  (0, 1, 0)   68.249842
#
# [64 rows x 2 columns]

# %%
best_model = SARIMAX(data['data'], order=(4,1,1)).fit()
print(best_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   data   No. Observations:                   83
# Model:               SARIMAX(4, 1, 1)   Log Likelihood                  76.099
# Date:                Wed, 13 Mar 2024   AIC                           -140.198
# Time:                        12:39:27   BIC                           -125.758
# Sample:                             0   HQIC                          -134.401
#                                  - 83
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7414      0.138     -5.379      0.000      -1.012      -0.471
# ar.L2         -0.6832      0.140     -4.879      0.000      -0.958      -0.409
# ar.L3         -0.6824      0.146     -4.681      0.000      -0.968      -0.397
# ar.L4          0.2212      0.144      1.541      0.123      -0.060       0.503
# ma.L1         -0.9093      0.071    -12.788      0.000      -1.049      -0.770
# sigma2         0.0082      0.001      5.579      0.000       0.005       0.011
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.38
# Prob(Q):                              0.99   Prob(JB):                         0.83
# Heteroskedasticity (H):               0.50   Skew:                            -0.03
# Prob(H) (two-sided):                  0.08   Kurtosis:                         2.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Ljung-Box test and Augmented Dickey-Fuller test
ljung_box, p_value = acorr_ljungbox(best_model.resid)

print(f'Ljung-Box test: {ljung_box[:10]}')
print(f'p-value: {p_value[:10]}')
# Out:
# Ljung-Box test: lb_stat
# p-value: lb_pvalue

# %%
plot_pacf(best_model.resid);
plot_acf(best_model.resid);
